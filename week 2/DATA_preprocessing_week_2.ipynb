# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("athlete_events.csv")

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
df.nlargest(2,'Height')
# Out:
#             ID      Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 265040  132627  Yao Ming   M  20.0   226.0   141.0  China  CHN  2000 Summer
# 265041  132627  Yao Ming   M  23.0   226.0   141.0  China  CHN  2004 Summer
#
#         Year  Season    City       Sport                        Event Medal
# 265040  2000  Summer  Sydney  Basketball  Basketball Men's Basketball   NaN
# 265041  2004  Summer  Athina  Basketball  Basketball Men's Basketball   NaN

# %%
df.drop(columns={'ID','NOC','Games'},inplace=True)

# %%
df
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# 0                      A Dijiang   M  24.0   180.0    80.0           China
# 1                       A Lamusi   M  23.0   170.0    60.0           China
# 2            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 271111                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 271112                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271113                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271114        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 271115        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
#         Year  Season            City          Sport  \
# ...

# %%
df.nsmallest(1,'Age')
# Out:
#                       Name Sex   Age  Height  Weight  \
# 142882  Dimitrios Loundras   M  10.0     NaN     NaN
#
#                                  Team  Year  Season    City       Sport  \
# 142882  Ethnikos Gymnastikos Syllogos  1896  Summer  Athina  Gymnastics
#
#                                         Event   Medal
# 142882  Gymnastics Men's Parallel Bars, Teams  Bronze

# %%
gold=df.query("Medal=='Gold'")
gold_oldest=gold[gold['Age']==gold.Age.max()]
gold_oldest
# Out:
#                      Name Sex   Age  Height  Weight           Team  Year  \
# 105199    Charles Jacobus   M  64.0     NaN     NaN  United States  1904
# 233390  Oscar Gomer Swahn   M  64.0     NaN     NaN         Sweden  1912
#
#         Season       City     Sport  \
# 105199  Summer  St. Louis     Roque
# 233390  Summer  Stockholm  Shooting
#
#                                                    Event Medal
# 105199                               Roque Men's Singles  Gold
# 233390  Shooting Men's Running Target, Single Shot, Team  Gold

# %%
abc=df.query("Medal=='Gold'")
abc
# Out:
#                                        Name Sex   Age  Height  Weight  \
# 3                      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42                  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44                  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48                  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60                       Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...                                     ...  ..   ...     ...     ...
# 270981                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009                          Julia Zwehl   F  28.0   167.0    60.0
# 271016       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
#                   Team  Year  Season         City          Sport  \
# ...

# %%
young=df.query("Medal=='Silver'")
youngsilver=young[young['Age']==young.Age.min()]
youngsilver
# Out:
#                    Name Sex   Age  Height  Weight   Team  Year  Season  \
# 79024  Luigina Giavotti   F  11.0     NaN     NaN  Italy  1928  Summer
#
#             City       Sport                               Event   Medal
# 79024  Amsterdam  Gymnastics  Gymnastics Women's Team All-Around  Silver

# %%
event_occured=df['Year'].value_counts()
event_occured
# Out:
# Year
# 1992    16413
# 1988    14676
# 2000    13821
# 1996    13780
# 2016    13688
# 2008    13602
# 2004    13443
# 2012    12920
# 1972    11959
# 1984    11588
# 1976    10502
# 1968    10479
# 1964     9480
# 1952     9358
# 1960     9235
# 1980     8937
# 1948     7480
# 1936     7401
# 1956     6434
# 1924     5693
# 1928     5574
# 2014     4891
# 2010     4402
# 2006     4382
# 1920     4292
# 2002     4109
# 1912     4040
# 1998     3605
# 1932     3321
# 1994     3160
# 1908     3101
# 1900     1936
# 1906     1733
# 1904     1301
# 1896      380
# Name: count, dtype: int64

# %%
most_events_year = df['Year'].value_counts().idxmax()
most_events_year
# Out:
# np.int64(1992)

# %%
mey=pd.crosstab(df.Year,df.Event,margins=True)
mey
# Out:
# Event  Aeronautics Mixed Aeronautics  Alpine Skiing Men's Combined  \
# Year
# 1896                               0                             0
# 1900                               0                             0
# 1904                               0                             0
# 1906                               0                             0
# 1908                               0                             0
# 1912                               0                             0
# 1920                               0                             0
# 1924                               0                             0
# 1928                               0                             0
# 1932                               0                             0
# 1936                               1                            66
# 1948                               0                            79
# 1952                               0                             0
# ...

# %%
total_medals=df.groupby(['Team'])['Medal'].count()
total_medals.nlargest(2,keep='all')
# Out:
# Team
# United States    5219
# Soviet Union     2451
# Name: Medal, dtype: int64

# %%
events_by_year = df.groupby('Year')['Event'].nunique()
events_by_year
# Out:
# Year
# 1896     43
# 1900     90
# 1904     95
# 1906     74
# 1908    109
# 1912    107
# 1920    158
# 1924    148
# 1928    136
# 1932    145
# 1936    167
# 1948    175
# 1952    171
# 1956    175
# 1960    177
# 1964    197
# 1968    207
# 1972    228
# 1976    235
# 1980    241
# 1984    260
# 1988    283
# 1992    314
# 1994     61
# 1996    271
# 1998     68
# 2000    300
# 2002     78
# 2004    301
# 2006     84
# 2008    302
# 2010     86
# 2012    302
# 2014     98
# 2016    306
# Name: Event, dtype: int64

# %%
events_by_sport = df.groupby('Sport')['Event'].nunique()
events_by_sport
# Out:
# Sport
# Aeronautics          1
# Alpine Skiing       10
# Alpinism             1
# Archery             29
# Art Competitions    29
#                     ..
# Tug-Of-War           1
# Volleyball           2
# Water Polo           2
# Weightlifting       21
# Wrestling           30
# Name: Event, Length: 66, dtype: int64

# %%
df['Event'].value_counts()
# Out:
# Event
# Football Men's Football                                5733
# Ice Hockey Men's Ice Hockey                            4762
# Hockey Men's Hockey                                    3958
# Water Polo Men's Water Polo                            3358
# Basketball Men's Basketball                            3280
#                                                        ...
# Archery Men's Target Archery, 50 metres, Individual       2
# Archery Men's Target Archery, 33 metres, Individual       2
# Croquet Mixed Doubles                                     2
# Archery Men's Target Archery, 28 metres, Individual       2
# Aeronautics Mixed Aeronautics                             1
# Name: count, Length: 765, dtype: int64

# %%
nop=df['Team'].value_counts()
nop
# Out:
# Team
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
#                  ...
# Danzig               1
# Formosa              1
# Cuxhaven             1
# Camille              1
# Hamburg              1
# Name: count, Length: 1184, dtype: int64

# %%
usa=df[df['Team']=='United States']
asd=pd.crosstab(usa.Year,usa.Medal)
asd
# Out:
# Medal  Bronze  Gold  Silver
# Year
# 1896        2    11       7
# 1900       13    18      14
# 1904       66    65      68
# 1906        6    12       6
# 1908       15    34      16
# 1912       36    46      25
# 1920       38   111      45
# 1924       50    92      44
# 1928       19    48      25
# 1932       62    71      57
# 1936       28    51      29
# 1948       33    82      34
# 1952       29    77      38
# 1956       21    61      61
# 1960       21    97      27
# 1964       32    96      37
# 1968       36   100      37
# 1972       46    72      77
# 1976       39    73      61
# 1980        2    24       4
# 1984       50   190     119
# 1988       56    89      67
# 1992       87    92      57
# 1994        5     6       8
# 1996       52   157      46
# 1998        3    25       2
# 2000       51   128      61
# 2002        9     9      52
# 2004       69   115      75
# 2006       32     9       7
# 2008       78   121     110
# 2010       20     8      61
# ...

# %%
df.query("Year == 1992 & Medal == 'Gold' & Sport == 'basketball'")
# Out:
# Empty DataFrame
# Columns: [Name, Sex, Age, Height, Weight, Team, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
df.query("Year == 1992 & Sport == 'Basketball' & Medal == 'Gold'")
# Out:
#                                                      Name Sex   Age  Height  \
# 14220                          Yelena Viktorovna Baranova   F  20.0   192.0
# 14656                                Charles Wade Barkley   M  29.0   198.0
# 22150                                      Larry Joe Bird   M  35.0   205.0
# 31954                Elen Rafaelovna Bunatyants-Shakirova   F  22.0   190.0
# 58646                                Clyde Austin Drexler   M  30.0   200.0
# 65566                              Patrick Aloysius Ewing   M  29.0   213.0
# 78340                            Irina Yakovlevna Gerlits   F  26.0   190.0
# 109625                        Earvin "Magic" Johnson, Jr.   M  32.0   205.0
# 110517                             Michael Jeffrey Jordan   M  29.0   198.0
# 117541                      Yelena Anatolyevna Khudashova   F  27.0   195.0
# 130713                          Christian Donald Laettner   M  22.0   211.0
# ...

# %%
df.Medal.unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
df['Gold'] = [1 if medal == 'Gold' else 0 for medal in df['Medal']]
df['Silver'] = [1 if medal == 'Silver' else 0 for medal in df['Medal']]
df['Bronze'] = [1 if medal =='Bronze' else 0 for medal in df['Medal']]

# %%
df.head()
# Out:
#                        Name Sex   Age  Height  Weight            Team  Year  \
# 0                 A Dijiang   M  24.0   180.0    80.0           China  1992
# 1                  A Lamusi   M  23.0   170.0    60.0           China  2012
# 2       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  1920
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  1900
# 4  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  1988
#
#    Season       City          Sport                             Event Medal  \
# 0  Summer  Barcelona     Basketball       Basketball Men's Basketball   NaN
# 1  Summer     London           Judo      Judo Men's Extra-Lightweight   NaN
# 2  Summer  Antwerpen       Football           Football Men's Football   NaN
# 3  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres   NaN
#
#    Gold  Silver  Bronze
# 0     0       0       0
# ...

# %%
aasb=df.groupby(['Team'])[['Gold','Silver','Bronze']].sum()
aasb
# Out:
#                        Gold  Silver  Bronze
# Team
# 30. Februar               0       0       0
# A North American Team     0       0       4
# Acipactli                 0       0       0
# Acturus                   0       0       0
# Afghanistan               0       0       2
# ...                     ...     ...     ...
# Zambia                    0       1       1
# Zefyros                   0       0       0
# Zimbabwe                 17       4       1
# Zut                       0       3       0
# rn-2                      0       0       0
#
# [1184 rows x 3 columns]

# %%
aasb['Total']=aasb['Gold']+aasb['Silver']+aasb['Bronze']
aasb.Total
# Out:
# Team
# 30. Februar               0
# A North American Team     4
# Acipactli                 0
# Acturus                   0
# Afghanistan               2
#                          ..
# Zambia                    2
# Zefyros                   0
# Zimbabwe                 22
# Zut                       3
# rn-2                      0
# Name: Total, Length: 1184, dtype: int64

# %%
aasb.sort_values(by='Total',ascending=False)
# Out:
#                  Gold  Silver  Bronze  Total
# Team
# United States    2474    1512    1233   5219
# Soviet Union     1058     716     677   2451
# Germany           679     627     678   1984
# Great Britain     519     582     572   1673
# France            455     518     577   1550
# ...               ...     ...     ...    ...
# Wendehals           0       0       0      0
# Glisten             0       0       0      0
# Gran Gesto          0       0       0      0
# Great Britain-4     0       0       0      0
# West Germany-3      0       0       0      0
#
# [1184 rows x 4 columns]

# %%
aasb.nlargest(3,'Total')
# Out:
#                Gold  Silver  Bronze  Total
# Team
# United States  2474    1512    1233   5219
# Soviet Union   1058     716     677   2451
# Germany         679     627     678   1984

# %%
aasb['Total'].max()
# Out:
# np.int64(5219)

# %%
no_g_medal=aasb[aasb['Gold']==0]
no_g_medal
# Out:
#                        Gold  Silver  Bronze  Total
# Team
# 30. Februar               0       0       0      0
# A North American Team     0       0       4      4
# Acipactli                 0       0       0      0
# Acturus                   0       0       0      0
# Afghanistan               0       0       2      2
# ...                     ...     ...     ...    ...
# Yugoslavia-2              0       0       0      0
# Zambia                    0       1       1      2
# Zefyros                   0       0       0      0
# Zut                       0       3       0      3
# rn-2                      0       0       0      0
#
# [942 rows x 4 columns]

# %%
zero_medal_country=df.query("Gold==0 & Silver==0 & Bronze==0")
zero_medal_country
# Out:
#                             Name Sex   Age  Height  Weight         Team  Year  \
# 0                      A Dijiang   M  24.0   180.0    80.0        China  1992
# 1                       A Lamusi   M  23.0   170.0    60.0        China  2012
# 2            Gunnar Nielsen Aaby   M  24.0     NaN     NaN      Denmark  1920
# 4       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  1988
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  1988
# ...                          ...  ..   ...     ...     ...          ...   ...
# 271111                Andrzej ya   M  29.0   179.0    89.0     Poland-1  1976
# 271112                  Piotr ya   M  27.0   176.0    59.0       Poland  2014
# 271113                  Piotr ya   M  27.0   176.0    59.0       Poland  2014
# 271114        Tomasz Ireneusz ya   M  30.0   185.0    96.0       Poland  1998
# 271115        Tomasz Ireneusz ya   M  34.0   185.0    96.0       Poland  2002
#
# ...

# %%
is_india_in_zero_medal_country='India'in zero_medal_country['Team'].value_counts()
is_india_in_zero_medal_country
# Out:
# True

# %%
df.Team.unique()
# Out:
# array(['China', 'Denmark', 'Denmark/Sweden', ..., 'Solos Carex',
#        'Dow Jones', 'Digby'], shape=(1184,), dtype=object)

# %%
tab= pd.crosstab(index=df.Team, columns=df.Year, values=df.Gold, aggfunc='sum')
tab.loc['India']
# Out:
# Year
# 1896     NaN
# 1900     0.0
# 1904     NaN
# 1906     NaN
# 1908     NaN
# 1912     NaN
# 1920     0.0
# 1924     7.0
# 1928    14.0
# 1932    15.0
# 1936    19.0
# 1948    20.0
# 1952    14.0
# 1956    17.0
# 1960     0.0
# 1964    15.0
# 1968     0.0
# 1972     0.0
# 1976     0.0
# 1980    16.0
# 1984     0.0
# 1988     0.0
# 1992     0.0
# 1994     NaN
# 1996     0.0
# 1998     0.0
# 2000     0.0
# 2002     0.0
# 2004     0.0
# 2006     0.0
# 2008     1.0
# 2010     0.0
# 2012     0.0
# 2014     0.0
# 2016     0.0
# Name: India, dtype: float64

# %%
basketball=df[df['Sport']=='Basketball']
basketball
# Out:
#                                       Name Sex   Age  Height  Weight  \
# 0                                A Dijiang   M  24.0   180.0    80.0
# 167                      Tamara Abalde Daz   F  19.0   185.0    72.0
# 250                  Youssef Mohamed Abbas   M  31.0     NaN     NaN
# 264                       Alessandro Abbio   M  29.0   195.0    85.0
# 346     Ahmed El-Sayed Abdel Hamid Mobarak   M  25.0   189.0    85.0
# ...                                    ...  ..   ...     ...     ...
# 270742                  Eurelijus ukauskas   M  30.0   218.0   115.0
# 270743                  Mindaugas ukauskas   M  20.0   201.0   100.0
# 270744                  Mindaugas ukauskas   M  28.0   201.0   100.0
# 271026                      Philip Zwiener   M  23.0   202.0    98.0
# 271110              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#              Team  Year  Season            City       Sport  \
# 0           China  1992  Summer       Barcelona  Basketball
# ...

# %%
basketball.Height.max()
# Out:
# np.float64(226.0)

# %%
basketball.query("Height==226")
# Out:
#             Name Sex   Age  Height  Weight   Team  Year  Season     City  \
# 265040  Yao Ming   M  20.0   226.0   141.0  China  2000  Summer   Sydney
# 265041  Yao Ming   M  23.0   226.0   141.0  China  2004  Summer   Athina
# 265042  Yao Ming   M  27.0   226.0   141.0  China  2008  Summer  Beijing
#
#              Sport                        Event Medal  Gold  Silver  Bronze  \
# 265040  Basketball  Basketball Men's Basketball   NaN     0       0       0
# 265041  Basketball  Basketball Men's Basketball   NaN     0       0       0
# 265042  Basketball  Basketball Men's Basketball   NaN     0       0       0
#
#         Total
# 265040      0
# 265041      0
# 265042      0

# %%
hosted_city=df.groupby(['City','Season'])['Year'].value_counts()
hosted_city
# Out:
# City                    Season  Year
# Albertville             Winter  1992     3436
# Amsterdam               Summer  1928     4992
# Antwerpen               Summer  1920     4292
# Athina                  Summer  2004    13443
#                                 1906     1733
#                                 1896      380
# Atlanta                 Summer  1996    13780
# Barcelona               Summer  1992    12977
# Beijing                 Summer  2008    13602
# Berlin                  Summer  1936     6506
# Calgary                 Winter  1988     2639
# Chamonix                Winter  1924      460
# Cortina d'Ampezzo       Winter  1956     1307
# Garmisch-Partenkirchen  Winter  1936      895
# Grenoble                Winter  1968     1891
# Helsinki                Summer  1952     8270
# Innsbruck               Winter  1976     1861
#                                 1964     1778
# Lake Placid             Winter  1980     1746
#                                 1932      352
# ...

# %%
hosted_city=df.groupby(['City', 'Season'])['Year'].value_counts().idxmax()
hosted_city
# Out:
# ('Sydney', 'Summer', np.int64(2000))

# %%
hosted_city=df.groupby(['City', 'Season'])['Year'].value_counts().idxmin()
hosted_city
# Out:
# ('Stockholm', 'Summer', np.int64(1956))

# %%
gold_medal=df[df['Medal']=='Gold']
gold_medal
# Out:
#                                        Name Sex   Age  Height  Weight  \
# 3                      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42                  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44                  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48                  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60                       Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...                                     ...  ..   ...     ...     ...
# 270981                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009                          Julia Zwehl   F  28.0   167.0    60.0
# 271016       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
#                   Team  Year  Season         City          Sport  \
# ...

# %%
gold_medal[gold_medal['Age']==gold_medal.Age.min()]
# Out:
#                                       Name Sex   Age  Height  Weight  \
# 27207                        Hans Bourquin   M  13.0     NaN     NaN
# 52010   Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 73581                           Fu Mingxia   F  13.0   160.0    48.0
# 78544         Marjorie Gestring (-Redlick)   F  13.0     NaN     NaN
# 119277                          Kim Yun-Mi   F  13.0   160.0    48.0
# 200704       Aileen Muriel Riggin (-Soule)   F  13.0   142.0     NaN
# 268602                         Klaus Zerta   M  13.0   165.0    48.0
#
#                  Team  Year  Season         City                      Sport  \
# 27207     Switzerland  1928  Summer    Amsterdam                     Rowing
# 52010   United States  1960  Summer         Roma                   Swimming
# 73581           China  1992  Summer    Barcelona                     Diving
# 78544   United States  1936  Summer       Berlin                     Diving
# ...

# %%
gold_medal[gold_medal['Name']==df.Gold.min()]
# Out:
# Empty DataFrame
# Columns: [Name, Sex, Age, Height, Weight, Team, Year, Season, City, Sport, Event, Medal, Gold, Silver, Bronze, Total]
# Index: []

# %%
gold_medal.Name.value_counts()
# Out:
# Name
# Michael Fred Phelps, II               23
# Raymond Clarence "Ray" Ewry           10
# Frederick Carlton "Carl" Lewis         9
# Larysa Semenivna Latynina (Diriy-)     9
# Paavo Johannes Nurmi                   9
#                                       ..
# Asen Ivanov Zlatev                     1
# Robert Zmlk                            1
# Kevin Lobdell Burnham                  1
# Hubertus Balthazar "Bart" Zoet         1
# Alejandro Abascal Garca                1
# Name: count, Length: 10413, dtype: int64
