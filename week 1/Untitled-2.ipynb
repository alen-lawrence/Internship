# %%
import pandas as pd
df=pd.read_csv("Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.dropna()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.rename(columns={'Annual Income (k$)':'annual income'},inplace=True)

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  annual income  Spending Score (1-100)
# 0           1    Male   19             15                      39
# 1           2    Male   21             15                      81
# 2           3  Female   20             16                       6
# 3           4  Female   23             16                      77
# 4           5  Female   31             17                      40

# %%
df.rename(columns={'Spending Score (1-100)':'spending score'},inplace=True)

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  annual income  spending score
# 0           1    Male   19             15              39
# 1           2    Male   21             15              81
# 2           3  Female   20             16               6
# 3           4  Female   23             16              77
# 4           5  Female   31             17              40

# %%
#line plot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
x=df['CustomerID']
y=df['annual income']
sns.lineplot(x=x,y=y)
plt.title("asdf")
plt.xlabel("customer id")
plt.ylabel("annual income")
plt.show()

# %%
#scatter plot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
x=df['Age']
y=df['spending score']
sns.scatterplot(x=x,y=y)
plt.title("asdf")
plt.xlabel("age")
plt.ylabel("spending score")
plt.show()

# %%
#histogram
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
x=df['spending score']
sns.histplot(x=x,kde=30,bins=20)
plt.show()

# %%
#box plot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x=df['Genre'],y=df['annual income'],palette='dark')
plt.show()
# Out:
# C:\Users\alenl\AppData\Local\Temp\ipykernel_16724\702239761.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Genre'],y=df['annual income'],palette='dark')

# %%
#bar plot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
x=df['annual income']
y=df['Age']
sns.barplot(x=x,y=y,palette='dark')
plt.show()
# Out:
# C:\Users\alenl\AppData\Local\Temp\ipykernel_16724\2664512326.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x,y=y,palette='dark')

# %%
#heatmap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#df=df.drop('Genre',axis=1)

sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
print(df.corr())
# Out:
#                 CustomerID       Age  annual income  spending score
# CustomerID        1.000000 -0.026763       0.977548        0.013835
# Age              -0.026763  1.000000      -0.012398       -0.327227
# annual income     0.977548 -0.012398       1.000000        0.009903
# spending score    0.013835 -0.327227       0.009903        1.000000

# %%
df.head(10)
# Out:
#    CustomerID  Age  annual income  spending score
# 0           1   19             15              39
# 1           2   21             15              81
# 2           3   20             16               6
# 3           4   23             16              77
# 4           5   31             17              40
# 5           6   22             17              76
# 6           7   35             18               6
# 7           8   23             18              94
# 8           9   64             19               3
# 9          10   30             19              72

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df,hue='annual income',hue_order=,palette='dark')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df,hue='spending score',palette='RdYlBu')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df,hue='Age',palette='RdYlBu')
plt.show()
